# %%
import pandas as pd

# %%
# !ls ../..
# Out:
# anthropic       deeplearning_ai python          teaching
# coursera        java            README.md       tf
# data            llm             skolar
