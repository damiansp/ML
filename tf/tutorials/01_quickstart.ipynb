# %%
import ssl

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential


ssl._create_default_https_context = ssl._create_unverified_context
tf.__version__
# Out:
# '2.20.0'

# %%
IMG_SHAPE = (28, 28)
N_YS = 10

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train / 255.
x_test = x_test / 255.

# %%
mod = Sequential([
    Flatten(input_shape=IMG_SHAPE),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(N_YS, activation='softmax')])
mod.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mod.fit(x_train, y_train, epochs=5)
mod.evaluate(x_test, y_test, verbose=2)
# Out:
# Epoch 1/5
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9143 - loss: 0.2950
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9573 - loss: 0.1411
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9672 - loss: 0.1074
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9733 - loss: 0.0853
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9765 - loss: 0.0733
# 313/313 - 0s - 598us/step - accuracy: 0.9777 - loss: 0.0681
# [0.06814880669116974, 0.9776999950408936]
