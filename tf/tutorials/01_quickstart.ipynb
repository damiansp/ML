# %%
import ssl

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Sequential


ssl._create_default_https_context = ssl._create_unverified_context

# %%
IMG_SHAPE = (28, 28)
N_YS = 10

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train / 255.
x_test = x_test / 255.

# %%
mod = Sequential([
    Flatten(input_shape=IMG_SHAPE),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(N_YS, activation='softmax')])
mod.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mod.fit(x_train, y_train, epochs=5)
mod.evaluate(x_test, y_test)
# Out:
# /Users/damiansp/.venv/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 850us/step - accuracy: 0.8555 - loss: 0.4908
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 854us/step - accuracy: 0.9558 - loss: 0.1485
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 840us/step - accuracy: 0.9676 - loss: 0.1089
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 850us/step - accuracy: 0.9732 - loss: 0.0875
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 869us/step - accuracy: 0.9770 - loss: 0.0752
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 429us/step - accuracy: 0.9728 - loss: 0.0896
# [0.07232963293790817, 0.977400004863739]
